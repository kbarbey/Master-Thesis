# %%
import os
import pickle
from sparta.Auxil.PeriodicityDetector import PeriodicityDetector
from sparta.UNICOR.Spectrum import Spectrum
from sparta.UNICOR.Template import Template
from sparta.Auxil.TimeSeries import TimeSeries
from sparta.Observations import Observations
import numpy as np
import pandas as pd

# %%
# DATA PARAMETERS

survey = "CORALIE" # survey name
sample_rate = 1 # sample rate of the data
min_wv = 4400 # minimum wavelength of the data
max_wv = 4600 # maximum wavelength of the data
spec_dir = r"C:\Users\kentb\Desktop\PDM\data\Coralie14\spectra\ASASJ103158-5814.7_Coralie14_s1d" # directory of the spectrum
rv_dir = r"C:\Users\kentb\Desktop\PDM\data\Coralie14\RV\ASASJ103158-5814.7_CORALIE14.csv" # directory of the RVs
results_dir = r"C:\Users\kentb\Desktop\PDM\data\products\Coralie14\ASAS" # directory of the results

# %%
obs_data = Observations(survey=survey, sample_rate=sample_rate, min_wv=min_wv, max_wv=max_wv,
                        target_visits_lib=spec_dir,find_beggining=True)
df = pd.read_csv(rv_dir)
rv = df.rv.astype(float).values
e_rv = df.rv_err.astype(float).values
times = df.bjd.astype(float).values
times = times+2400000# - int(min(obs_data.time_series.times))
# Out:
# let's goooo
# Using target_visits_lib: C:\Users\kentb\Desktop\PDM\data\Coralie14\spectra\ASASJ103158-5814.7_Coralie14_s1d
# Selected directory: C:\Users\kentb\Desktop\PDM\data\Coralie14\spectra\ASASJ103158-5814.7_Coralie14_s1d
# CORALIE.2018-03-02T07_01_30.000_s1d_A.fits
# CORALIE.2018-03-04T05_11_22.000_s1d_A.fits
# CORALIE.2018-03-05T03_56_07.000_s1d_A.fits
# CORALIE.2018-03-06T03_28_45.000_s1d_A.fits
# CORALIE.2018-03-07T04_54_53.000_s1d_A.fits
# CORALIE.2018-03-08T05_26_21.000_s1d_A.fits
# CORALIE.2018-03-09T03_00_43.000_s1d_A.fits
# CORALIE.2018-03-10T05_55_19.000_s1d_A.fits
# CORALIE.2018-03-11T05_43_06.000_s1d_A.fits
# CORALIE.2018-03-12T05_28_26.000_s1d_A.fits
# CORALIE.2018-03-12T23_59_49.000_s1d_A.fits
# CORALIE.2018-03-14T04_07_14.000_s1d_A.fits
# CORALIE.2018-03-15T03_14_36.000_s1d_A.fits
# CORALIE.2018-03-16T03_44_28.000_s1d_A.fits
# CORALIE.2018-04-18T01_39_21.000_s1d_A.fits
# CORALIE.2018-04-19T02_58_40.000_s1d_A.fits
# CORALIE.2018-04-20T04_06_58.000_s1d_A.fits
# CORALIE.2018-04-21T05_07_51.000_s1d_A.fits
# CORALIE.2018-04-22T02_13_16.000_s1d_A.fits
# CORALIE.2018-04-23T00_50_31.000_s1d_A.fits
# CORALIE.2018-04-24T00_23_34.000_s1d_A.fits
# CORALIE.2018-04-25T04_35_30.000_s1d_A.fits
# CORALIE.2018-04-27T02_08_47.000_s1d_A.fits
# CORALIE.2018-04-28T02_03_48.000_s1d_A.fits
# CORALIE.2018-04-29T02_29_28.000_s1d_A.fits
# CORALIE.2018-04-30T02_20_08.000_s1d_A.fits
# CORALIE.2018-05-01T00_22_29.000_s1d_A.fits
# CORALIE.2018-05-23T00_55_10.000_s1d_A.fits
# CORALIE.2018-05-24T02_34_23.000_s1d_A.fits
# CORALIE.2018-05-25T00_57_39.000_s1d_A.fits
# CORALIE.2018-05-26T00_34_50.000_s1d_A.fits
# CORALIE.2018-05-26T23_27_33.000_s1d_A.fits
# CORALIE.2018-05-27T23_17_24.000_s1d_A.fits
# CORALIE.2018-05-31T23_06_03.000_s1d_A.fits
# CORALIE.2018-06-01T23_03_40.000_s1d_A.fits
# CORALIE.2018-06-03T00_25_15.000_s1d_A.fits
# CORALIE.2018-06-03T23_21_35.000_s1d_A.fits
# CORALIE.2018-06-04T23_04_11.000_s1d_A.fits
# CORALIE.2019-01-27T05_25_50.000_s1d_A.fits
# CORALIE.2019-01-28T05_43_58.000_s1d_A.fits
# CORALIE.2019-01-29T06_23_25.000_s1d_A.fits
# CORALIE.2019-01-31T06_36_05.000_s1d_A.fits
# CORALIE.2019-02-01T03_33_51.000_s1d_A.fits
# CORALIE.2019-02-02T03_54_27.000_s1d_A.fits
# CORALIE.2019-02-02T07_27_01.000_s1d_A.fits
# CORALIE.2019-02-03T03_49_29.000_s1d_A.fits
# CORALIE.2019-02-03T08_10_27.000_s1d_A.fits
# CORALIE.2019-02-04T03_04_08.000_s1d_A.fits
# CORALIE.2019-02-05T02_38_07.000_s1d_A.fits
# CORALIE.2019-02-05T07_00_48.000_s1d_A.fits
# CORALIE.2019-02-06T03_14_53.000_s1d_A.fits
# CORALIE.2019-02-06T08_54_13.000_s1d_A.fits
# CORALIE.2019-02-07T08_06_03.000_s1d_A.fits
# CORALIE.2019-02-08T03_51_51.000_s1d_A.fits
# CORALIE.2019-02-08T07_45_57.000_s1d_A.fits
# CORALIE.2019-03-07T02_13_00.000_s1d_A.fits
# CORALIE.2019-03-07T08_02_06.000_s1d_A.fits
# CORALIE.2019-03-08T02_13_01.000_s1d_A.fits
# CORALIE.2019-03-08T07_15_43.000_s1d_A.fits
# CORALIE.2019-03-09T01_06_34.000_s1d_A.fits
# CORALIE.2019-03-09T07_50_23.000_s1d_A.fits
# CORALIE.2019-03-10T04_49_51.000_s1d_A.fits
# CORALIE.2019-03-10T08_03_41.000_s1d_A.fits
# CORALIE.2019-03-11T01_20_30.000_s1d_A.fits
# CORALIE.2019-03-11T08_27_32.000_s1d_A.fits
# CORALIE.2019-03-12T01_10_58.000_s1d_A.fits
# CORALIE.2019-03-13T05_54_54.000_s1d_A.fits
# CORALIE.2019-03-14T06_53_16.000_s1d_A.fits
# CORALIE.2019-03-15T00_53_08.000_s1d_A.fits
# CORALIE.2019-03-15T07_13_45.000_s1d_A.fits
# CORALIE.2019-03-16T00_04_53.000_s1d_A.fits
# CORALIE.2019-03-16T07_52_28.000_s1d_A.fits
# CORALIE.2019-04-06T05_13_20.000_s1d_A.fits
# CORALIE.2019-04-07T03_03_21.000_s1d_A.fits
# CORALIE.2019-04-08T03_49_12.000_s1d_A.fits
# CORALIE.2019-04-09T02_04_19.000_s1d_A.fits
# CORALIE.2019-04-10T03_50_12.000_s1d_A.fits
# CORALIE.2019-04-11T02_52_41.000_s1d_A.fits
# CORALIE.2019-04-12T03_41_48.000_s1d_A.fits
# CORALIE.2019-04-13T00_57_20.000_s1d_A.fits
# CORALIE.2019-04-14T03_11_54.000_s1d_A.fits
# CORALIE.2019-04-15T00_04_32.000_s1d_A.fits
# CORALIE.2019-04-16T04_28_33.000_s1d_A.fits
# CORALIE.2019-04-17T01_59_04.000_s1d_A.fits
# CORALIE.2019-04-18T03_47_25.000_s1d_A.fits
# CORALIE.2019-04-19T02_40_20.000_s1d_A.fits
# CORALIE.2019-05-06T02_31_12.000_s1d_A.fits
# CORALIE.2019-05-07T23_56_08.000_s1d_A.fits
# CORALIE.2019-05-10T02_47_18.000_s1d_A.fits
# CORALIE.2019-05-11T02_07_29.000_s1d_A.fits
# CORALIE.2019-05-12T01_24_48.000_s1d_A.fits
# CORALIE.2019-05-14T03_01_06.000_s1d_A.fits
# CORALIE.2019-05-16T02_04_09.000_s1d_A.fits
# CORALIE.2019-05-17T01_39_10.000_s1d_A.fits
# CORALIE.2021-04-20T04_13_02.000_s1d_A.fits
# CORALIE.2021-04-23T02_36_20.000_s1d_A.fits
# CORALIE.2021-04-24T01_15_30.000_s1d_A.fits
# CORALIE.2021-04-25T04_28_51.000_s1d_A.fits
# CORALIE.2021-04-26T04_16_05.000_s1d_A.fits
# CORALIE.2021-05-05T02_15_01.000_s1d_A.fits
# CORALIE.2021-05-06T00_41_26.000_s1d_A.fits
# CORALIE.2021-05-07T03_11_23.000_s1d_A.fits
# CORALIE.2021-05-08T02_37_36.000_s1d_A.fits
# CORALIE.2021-05-09T02_46_07.000_s1d_A.fits
# CORALIE.2021-05-10T02_03_14.000_s1d_A.fits
# CORALIE.2021-05-15T03_57_48.000_s1d_A.fits
# CORALIE.2021-05-16T01_33_00.000_s1d_A.fits
# CORALIE.2021-05-17T03_50_41.000_s1d_A.fits
# CORALIE.2021-11-10T08_14_20.000_s1d_A.fits
# CORALIE.2021-11-14T08_28_48.000_s1d_A.fits
# CORALIE.2021-12-23T07_20_08.000_s1d_A.fits
# CORALIE.2021-12-29T08_03_27.000_s1d_A.fits
# CORALIE.2022-01-01T05_19_45.000_s1d_A.fits
# CORALIE.2022-01-04T06_44_55.000_s1d_A.fits
# CORALIE.2022-01-07T06_22_04.000_s1d_A.fits
# CORALIE.2022-01-16T06_18_30.000_s1d_A.fits
# CORALIE.2022-12-03T08_10_26.000_s1d_A.fits
# CORALIE.2022-12-11T08_10_19.000_s1d_A.fits
# CORALIE.2022-12-14T08_15_28.000_s1d_A.fits
# CORALIE.2022-12-17T08_17_04.000_s1d_A.fits
# CORALIE.2022-12-18T08_10_50.000_s1d_A.fits
# CORALIE.2022-12-19T08_20_03.000_s1d_A.fits
# CORALIE.2022-12-20T07_46_02.000_s1d_A.fits
# CORALIE.2022-12-21T08_00_40.000_s1d_A.fits
# CORALIE.2022-12-22T07_58_18.000_s1d_A.fits
# CORALIE.2022-12-23T08_29_07.000_s1d_A.fits
# CORALIE.2023-01-11T07_44_23.000_s1d_A.fits
# CORALIE.2023-01-12T08_17_54.000_s1d_A.fits
# CORALIE.2023-01-13T08_08_36.000_s1d_A.fits
# CORALIE.2023-01-14T07_28_23.000_s1d_A.fits
# CORALIE.2023-01-15T05_31_35.000_s1d_A.fits
# CORALIE.2023-01-16T05_41_03.000_s1d_A.fits
# CORALIE.2023-01-17T04_39_06.000_s1d_A.fits
# CORALIE.2023-01-18T06_32_38.000_s1d_A.fits
# CORALIE.2023-01-19T08_38_48.000_s1d_A.fits
# CORALIE.2023-01-20T05_47_11.000_s1d_A.fits
# CORALIE.2023-01-29T03_22_55.000_s1d_A.fits
# CORALIE.2023-01-30T03_57_12.000_s1d_A.fits
# CORALIE.2023-01-31T05_07_17.000_s1d_A.fits
# CORALIE.2023-02-01T06_55_37.000_s1d_A.fits
# CORALIE.2023-02-02T04_57_19.000_s1d_A.fits
# CORALIE.2023-02-03T07_36_52.000_s1d_A.fits
# CORALIE.2023-02-04T05_19_42.000_s1d_A.fits
# CORALIE.2023-02-05T03_37_18.000_s1d_A.fits
# CORALIE.2023-02-06T04_46_05.000_s1d_A.fits
# CORALIE.2023-02-07T05_51_51.000_s1d_A.fits
# CORALIE.2023-02-08T04_16_38.000_s1d_A.fits
# CORALIE.2023-02-09T05_37_19.000_s1d_A.fits
# CORALIE.2023-02-10T06_39_19.000_s1d_A.fits
# CORALIE.2023-02-11T05_17_22.000_s1d_A.fits
# CORALIE.2023-02-12T03_29_15.000_s1d_A.fits
# CORALIE.2023-02-13T04_38_05.000_s1d_A.fits
# CORALIE.2023-02-14T05_31_47.000_s1d_A.fits
# CORALIE.2023-02-15T04_45_50.000_s1d_A.fits
# CORALIE.2023-02-16T04_11_56.000_s1d_A.fits
# CORALIE.2023-02-17T04_13_53.000_s1d_A.fits
# CORALIE.2023-02-18T05_47_30.000_s1d_A.fits
# CORALIE.2023-02-19T04_25_49.000_s1d_A.fits
# CORALIE.2023-02-20T05_16_11.000_s1d_A.fits
# CORALIE.2023-02-22T04_22_33.000_s1d_A.fits
# CORALIE.2023-02-23T02_52_16.000_s1d_A.fits
# CORALIE.2023-02-25T04_58_22.000_s1d_A.fits
# CORALIE.2023-02-27T02_04_54.000_s1d_A.fits
# CORALIE.2023-02-28T03_31_29.000_s1d_A.fits
# CORALIE.2023-03-01T08_03_09.000_s1d_A.fits
# CORALIE.2023-03-02T04_36_26.000_s1d_A.fits
# CORALIE.2023-03-03T02_15_37.000_s1d_A.fits
# CORALIE.2023-03-04T03_43_53.000_s1d_A.fits
# CORALIE.2023-03-05T05_19_37.000_s1d_A.fits
# CORALIE.2023-03-06T05_22_01.000_s1d_A.fits
# CORALIE.2023-03-07T03_21_38.000_s1d_A.fits
# CORALIE.2023-03-08T06_19_50.000_s1d_A.fits
# CORALIE.2023-03-10T06_41_10.000_s1d_A.fits
# CORALIE.2023-03-10T07_57_15.000_s1d_A.fits
# CORALIE.2023-03-11T03_20_29.000_s1d_A.fits
# CORALIE.2023-03-12T05_42_46.000_s1d_A.fits
# CORALIE.2023-03-13T02_34_49.000_s1d_A.fits
# CORALIE.2023-03-14T04_47_01.000_s1d_A.fits
# CORALIE.2023-03-18T01_13_06.000_s1d_A.fits
# CORALIE.2023-03-19T05_05_13.000_s1d_A.fits
# CORALIE.2023-03-20T02_27_59.000_s1d_A.fits
# CORALIE.2023-03-22T03_17_42.000_s1d_A.fits
# CORALIE.2023-03-23T04_21_07.000_s1d_A.fits
# CORALIE.2023-03-25T00_13_47.000_s1d_A.fits
# CORALIE.2023-03-26T05_01_40.000_s1d_A.fits
# CORALIE.2023-03-27T06_11_44.000_s1d_A.fits
# CORALIE.2023-03-29T04_48_48.000_s1d_A.fits
# CORALIE.2023-03-31T02_58_33.000_s1d_A.fits
# CORALIE.2023-04-02T00_48_11.000_s1d_A.fits
# CORALIE.2023-04-03T02_32_27.000_s1d_A.fits
# CORALIE.2023-04-09T23_34_48.000_s1d_A.fits
# CORALIE.2023-04-11T02_35_53.000_s1d_A.fits
# CORALIE.2023-04-12T03_47_04.000_s1d_A.fits
# CORALIE.2023-04-13T02_12_15.000_s1d_A.fits
# CORALIE.2023-04-14T02_24_02.000_s1d_A.fits
# CORALIE.2023-04-15T02_05_57.000_s1d_A.fits
# CORALIE.2023-04-16T02_41_54.000_s1d_A.fits
# CORALIE.2023-04-17T02_46_25.000_s1d_A.fits
# CORALIE.2023-04-18T02_10_32.000_s1d_A.fits
# CORALIE.2023-04-20T03_34_35.000_s1d_A.fits
# CORALIE.2023-04-22T03_35_15.000_s1d_A.fits
# CORALIE.2023-04-23T04_20_52.000_s1d_A.fits
# CORALIE.2023-04-24T03_10_37.000_s1d_A.fits
# CORALIE.2023-04-25T03_08_49.000_s1d_A.fits
# CORALIE.2023-04-27T02_42_16.000_s1d_A.fits
# CORALIE.2023-04-27T23_21_38.000_s1d_A.fits
# CORALIE.2023-04-29T03_08_17.000_s1d_A.fits
# CORALIE.2023-04-30T02_21_22.000_s1d_A.fits
# CORALIE.2023-05-01T04_23_14.000_s1d_A.fits
# CORALIE.2023-05-01T23_55_09.000_s1d_A.fits
# CORALIE.2023-05-03T01_17_41.000_s1d_A.fits
# CORALIE.2023-05-03T23_06_49.000_s1d_A.fits
# CORALIE.2023-05-05T02_57_32.000_s1d_A.fits
# CORALIE.2023-05-06T01_55_23.000_s1d_A.fits
# CORALIE.2023-05-07T02_18_08.000_s1d_A.fits
# CORALIE.2023-05-09T23_05_38.000_s1d_A.fits
# CORALIE.2023-05-11T01_38_44.000_s1d_A.fits
# CORALIE.2023-05-12T00_49_27.000_s1d_A.fits
# CORALIE.2023-05-14T01_47_06.000_s1d_A.fits
# CORALIE.2023-05-15T01_58_32.000_s1d_A.fits
# CORALIE.2023-05-16T00_45_34.000_s1d_A.fits
# CORALIE.2023-05-18T01_51_42.000_s1d_A.fits
# CORALIE.2023-05-19T02_47_55.000_s1d_A.fits
# CORALIE.2023-05-19T23_30_05.000_s1d_A.fits
# CORALIE.2023-05-21T01_13_36.000_s1d_A.fits
# CORALIE.2023-05-22T01_33_51.000_s1d_A.fits
# CORALIE.2023-05-23T03_40_35.000_s1d_A.fits
# CORALIE.2023-05-24T01_37_02.000_s1d_A.fits
# CORALIE.2023-05-25T01_08_17.000_s1d_A.fits
# CORALIE.2023-05-27T00_35_24.000_s1d_A.fits
# CORALIE.2023-05-28T02_04_24.000_s1d_A.fits
# CORALIE.2023-06-04T01_01_34.000_s1d_A.fits
# CORALIE.2023-06-06T01_38_51.000_s1d_A.fits
# CORALIE.2023-06-07T23_37_55.000_s1d_A.fits
# CORALIE.2023-06-11T00_41_25.000_s1d_A.fits
# CORALIE.2023-06-12T00_20_00.000_s1d_A.fits
# CORALIE.2023-06-12T23_48_21.000_s1d_A.fits
# CORALIE.2023-06-14T23_10_38.000_s1d_A.fits
# CORALIE.2023-06-15T23_39_25.000_s1d_A.fits
# CORALIE.2023-06-16T23_28_59.000_s1d_A.fits
# CORALIE.2023-06-27T00_02_31.000_s1d_A.fits
# CORALIE.2023-06-28T00_36_00.000_s1d_A.fits
# CORALIE.2023-06-28T22_50_32.000_s1d_A.fits
# CORALIE.2023-06-29T23_32_10.000_s1d_A.fits

# %%
# Rearrange the RVs with the spectra

obs_data.rearrange_time_series(rv=rv, times=times)

# %%
obs_data.time_series.times = [i-int(min(times)) for i in obs_data.time_series.times]
times = times -int(min(times))

# %%
# Preprocess the spectra

for i in obs_data.time_series.vals:
    i = i.SpecPreProccess()

# %%
# PERIODOGRAM PARAMETERS

baseline = int(obs_data.time_series.times[-1])
min_freq = 1/1500 # Or maybe 1/2/baseline to be sure but let's test it that way.
max_freq = 1.5 # we don't expect more than one pulsation every two day so should be alright.
freq_range = (min_freq, max_freq) # frequency range of the periodograms
points_per_peak = 5
periodogram_grid_resolution = points_per_peak*max_freq*baseline # frequency resolution of the periodograms

# %%
print("Baseline: ", baseline)
# Out:
# Baseline:  3658

# %%
# Choosing frequency range and frequency resolution for the periodograms.
obs_data.initialize_periodicity_detector(freq_range=freq_range,
                                        periodogram_grid_resolution=periodogram_grid_resolution)

# %%
obs_data.periodicity_detector.calc_GLS()

print("GLS done", flush=True)

obs_data.periodicity_detector.calc_partial_periodogram(partial_type="shape")

print("Shape done",flush=True)

obs_data.periodicity_detector.calc_partial_periodogram(partial_type="shift")

print("Shift done",flush=True)

# file = open(os.path.join(results_dir, f"{spec_dir.rsplit('/',maxsplit=1)[-1]}_{str(min_wv)}_{str(max_wv)}.pkl"), 'wb')
# pickle.dump(obs_data, file)
# file.close()
# Out:
# GLS done
# Shape done
# Shift done

# %%
obs_data.periodicity_detector.period_truth = [1.1192]

# %%
# Plotting the periodograms

obs_data.periodicity_detector.plot_periodograms(annotate_pval=[1e-3], plot_rv=True,title=r"alfUmi 4400-4600 $\AA$", log_scale=False, plot_peaks=True)
# Out:
# No shape peaks found. Going with the highest peak in the shift periodogram.
# Relative error on period:  9.993266271475935e-06
# Max shift peak power:  0.49923219324081075

# %% [markdown]
# Polaris has its peak in the shift periodogram at 0.2519.
