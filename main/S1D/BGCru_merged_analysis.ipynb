# %%
import os
import pickle
from sparta.Auxil.PeriodicityDetector import PeriodicityDetector
from sparta.UNICOR.Spectrum import Spectrum
from sparta.UNICOR.Template import Template
from sparta.Auxil.TimeSeries import TimeSeries
from sparta.Observations import Observations
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
# Open the e2ds fits file
bgcru_e2ds = fits.open(r'C:\Users\kentb\Desktop\PDM\data\Coralie14\spectra\BGCru_Coralie14_e2ds\2015-05-11\CORALIE.2015-05-12T03_02_15.000_e2ds_A.fits')

# %%
data = bgcru_e2ds[0].data
#to access order i: data[i]. Each order has length 1952. There are 69 orders.
print(data[1])
bgcru_e2ds[0].header
# Out:
# 1952
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 1952 / length of data axis 1
# NAXIS2  =                   69 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# XSTART  =       0.00000000E+00 / xstart /
# XSTEP   =       1.00000000E+00 / xstep /
# YSTART  =       0.00000000E+00 / ystart /
# YSTEP   =       1.00000000E+00 / ystep /
# HIERARCH ESO CORA ATTCALIB = 3253 / attcalib  / att calib 0-4095
# HIERARCH ESO CORA ATTGUIDE = 3 / attguide  / att guid  1=max,3=min
# HIERARCH ESO CORA DATTCAL = -2 / sp.dattcal/ delta attcal debut-fin pose
# ...
